# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaviya2001/kaviya---mini-project/blob/main/Copy_of_MINI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("Rural Areas",limit=20,output_dir ='images',
                      adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/images/Rural Areas
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 20 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://static.tnc.news/2020/10/website-rrural.jpg
# [Error]Invalid image, not saving https://static.tnc.news/2020/10/website-rrural.jpg
#
# [!] Issue getting: https://static.tnc.news/2020/10/website-rrural.jpg
# [!] Error:: Invalid image, not saving https://static.tnc.news/2020/10/website-rrural.jpg
#
# [%] Downloading Image #1 from https://www.upforgrowth.org/sites/default/files/styles/insights_full_image/public/2020-09/shutterstock_620143919.jpg?itok=9f19G7qX
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://media.proprofs.com/images/discuss/user_images/153336/10182697922.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.familymoney.co.uk/wp-content/uploads/2018/07/wales-rural-home.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("urban areas",limit=20,output_dir ='images',
                      adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/images/urban areas
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 20 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://farm3.static.flickr.com/2204/1562862892_0f718edb0c_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://farm1.static.flickr.com/47/137348958_fc88be3d4c_o.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.researchgate.net/profile/Vicenc-Pala/publication/228901037/figure/fig3/AS:300890276810757@1448749240456/True-ortho-of-Barcelona_Q320.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.researchgate.net/profile/Vicenc-Pala/publication/228901037/figure/fig2/AS:300890276810756@1448749240432/Geometry-for-the-terrace-rails-effect_Q640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.researchgate.net/profile/Vicenc-Pala/publication/228901037/figure/fig4/AS:300890276810759@1448749240653/Perspective-combining-the-DEM-and-the-true-ortho_Q640.jpg
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize

# %%
import matplotlib.pyplot as plt

path = ('/content/images/urban areas/Image_1.jpg')
img = plt.imread(path)
plt.imshow(img)
img
# Out:
# array([[[ 84, 140, 217],
#         [ 84, 140, 215],
#         [ 84, 140, 215],
#         ...,
#         [ 85, 138, 206],
#         [ 85, 138, 206],
#         [ 85, 138, 206]],
#
#        [[ 83, 139, 216],
#         [ 83, 139, 214],
#         [ 83, 139, 214],
#         ...,
#         [ 84, 137, 205],
#         [ 84, 137, 205],
#         [ 84, 137, 205]],
#
#        [[ 82, 139, 216],
#         [ 82, 139, 216],
#         [ 82, 140, 214],
#         ...,
#         [ 84, 137, 205],
#         [ 84, 137, 205],
#         [ 83, 138, 205]],
#
#        ...,
#
#        [[ 59,  61,  76],
#         [ 52,  54,  67],
#         [ 55,  57,  70],
#         ...,
#         [ 61,  68,  24],
#         [ 70,  79,  24],
#         [ 69,  79,  26]],
#
#        [[ 64,  64,  76],
#         [ 58,  58,  70],
#         [ 57,  57,  69],
#         ...,
#         [ 47,  54,  13],
#         [ 58,  68,  16],
#         [ 74,  87,  33]],
#
#        [[ 63,  61,  72],
#         [ 60,  58,  69],
#         [ 56,  54,  65],
# ...

# %%
img.shape

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
datadir='/content/images'
categories = ['Rural Areas','urban areas']
images=[]
target = []
flat_data = []
for i in categories:
  path = os.path.join(datadir,i)
  for img in os.listdir(path):
     print(img)
     img_array = imread(os.path.join(path,img))
     img_resize = resize(img_array,(150,150,3))
     flat_data.append(np.ndarray.flatten(img_resize))
     target.append(i)
     plt.imshow(img_resize)
     plt.show()
flat_data = np.array(flat_data)
target = np.array(target)

# %%
from skimage.color import rgb2gray
img_resize = resize(img_array,(50,50))
img_gray = rgb2gray(img_resize)
plt.imshow(img_gray,cmap ='gray')
img_gray.size
# Out:
# 2500

# %%
df = pd.DataFrame(flat_data)
df['target'] = target
df
# Out:
#            0         1         2  ...     67498     67499       target
# 0   0.788235  0.776471  0.788235  ...  0.843137  0.858824  Rural Areas
# 1   0.129412  0.360784  0.580392  ...  0.250980  0.068627  Rural Areas
# 2   0.152102  0.252750  0.008627  ...  0.370703  0.273522  Rural Areas
# 3   0.471948  0.589595  0.692915  ...  0.251725  0.131572  Rural Areas
# 4   0.407843  0.709804  0.913725  ...  0.683137  0.368536  Rural Areas
# 5   0.044915  0.034552  0.015210  ...  0.283022  0.018447  Rural Areas
# 6   0.992157  0.992157  0.992157  ...  0.996078  0.996078  Rural Areas
# 7   0.996078  0.996078  0.996078  ...  0.612235  0.291561  Rural Areas
# 8   0.990451  0.990451  0.980647  ...  1.000000  1.000000  Rural Areas
# 9   0.070588  0.109804  0.003922  ...  0.431373  0.349020  Rural Areas
# 10  0.070588  0.109804  0.003922  ...  0.431373  0.349020  Rural Areas
# 11  0.901961  0.917647  0.921569  ...  0.538333  0.383761  Rural Areas
# ...
